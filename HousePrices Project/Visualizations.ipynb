# %%
import pandas as pd

import matplotlib.pyplot as plt

house_price_data_DF = pd.read_csv('Houseprices Dataset.csv')

plt.figure(figsize=(10,5)) # Size of the Figure Graph

plt.hist(house_price_data_DF['SalePrice']) # Create a histogram of a column in a Dataframe

plt.show()

# %%
#Boxplot

#Boxplot is used to look at he outliers

#Q2 -50percentile, Q1 - 25percentile, Q3 - 75percentile

#IQR =  Q3-Q1

#Outliers > Q3+1.5(IQR) and Outliers < Q1-1.5(IQR)

import pandas as pd

import matplotlib.pyplot as plt

house_price_data_DF = pd.read_csv('Houseprices Dataset.csv')

plt.figure(figsize=(10,10)) # Size of the Figure Graph

plt.boxplot(house_price_data_DF['SalePrice'])

plt.show()

# %%
import seaborn as sns

sns.distplot(house_price_data_DF['SalePrice']) #Gives Histogram

#sns.boxplot(house_price_data_DF['SalePrice'])

#sns.boxplot(house_price_data_DF['SalePrice'],orient ='v')

sns.boxplot(house_price_data_DF['LotShape'],house_price_data_DF['SalePrice']) # Between Categorical and the Continious Varible

# %%
#ScatterPlot

plt.scatter(house_price_data_DF['LotArea'],house_price_data_DF['SalePrice']) #Between Two Continious Varibles
